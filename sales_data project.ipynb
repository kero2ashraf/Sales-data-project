# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_csv(r"C:\Users\dell\OneDrive\Desktop\Data analytics files\Salary_Data.csv")
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6704 entries, 0 to 6703
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  6702 non-null   float64
#  1   Gender               6702 non-null   object
#  2   Education Level      6701 non-null   object
#  3   Job Title            6702 non-null   object
#  4   Years of Experience  6701 non-null   float64
#  5   Salary               6699 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 314.4+ KB

# %%
df.describe()
# Out:
#                Age  Years of Experience         Salary
# count  6702.000000          6701.000000    6699.000000
# mean     33.620859             8.094687  115326.964771
# std       7.614633             6.059003   52786.183911
# min      21.000000             0.000000     350.000000
# 25%      28.000000             3.000000   70000.000000
# 50%      32.000000             7.000000  115000.000000
# 75%      38.000000            12.000000  160000.000000
# max      62.000000            34.000000  250000.000000

# %%
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df.shape
# Out:
# (6704, 6)

# %%
df.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 5
# dtype: int64

# %%
num = df.select_dtypes("float").columns #name of columns that its type float
non_num = df.select_dtypes("object").columns #name of columns that its type is object

# %%
num
# Out:
# Index(['Age', 'Years of Experience', 'Salary'], dtype='object')

# %%
non_num
# Out:
# Index(['Gender', 'Education Level', 'Job Title'], dtype='object')

# %%
for col in non_num:
    print(df[col].unique())
# Out:
# ['Male' 'Female' nan 'Other']
# ["Bachelor's" "Master's" 'PhD' nan "Bachelor's Degree" "Master's Degree"
#  'High School' 'phD']
# ['Software Engineer' 'Data Analyst' 'Senior Manager' 'Sales Associate'
#  'Director' 'Marketing Analyst' 'Product Manager' 'Sales Manager'
#  'Marketing Coordinator' 'Senior Scientist' 'Software Developer'
#  'HR Manager' 'Financial Analyst' 'Project Manager' 'Customer Service Rep'
#  'Operations Manager' 'Marketing Manager' 'Senior Engineer'
#  'Data Entry Clerk' 'Sales Director' 'Business Analyst' 'VP of Operations'
#  'IT Support' 'Recruiter' 'Financial Manager' 'Social Media Specialist'
#  'Software Manager' 'Junior Developer' 'Senior Consultant'
#  'Product Designer' 'CEO' 'Accountant' 'Data Scientist'
#  'Marketing Specialist' 'Technical Writer' 'HR Generalist'
#  'Project Engineer' 'Customer Success Rep' 'Sales Executive' 'UX Designer'
#  'Operations Director' 'Network Engineer' 'Administrative Assistant'
# ...

# %%
df["Job Title"].value_counts()
# Out:
# Software Engineer             518
# Data Scientist                453
# Software Engineer Manager     376
# Data Analyst                  363
# Senior Project Engineer       318
#                              ...
# Account Manager                 1
# Help Desk Analyst               1
# Senior Training Specialist      1
# Junior Web Designer             1
# Supply Chain Analyst            1
# Name: Job Title, Length: 193, dtype: int64

# %%
df["Job Title"].nunique() #this function used to get the length
# Out:
# 193

# %%
df["Education Level"] = df["Education Level"].replace({"Bachelor's" : "Bachelor's Degree" , "Master's" : "Master's Degree" 
                                                      , "phD" : "PhD"})
df["Education Level"].value_counts()
# Out:
# Bachelor's Degree    3023
# Master's Degree      1861
# PhD                  1369
# High School           448
# Name: Education Level, dtype: int64

# %%
#COUNT the number of males and females
gender_counts = df["Gender"].value_counts()
#create a bar chart
gender_counts.plot(kind="bar",rot=0)
plt.title("Number of Males and Females")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
df.head()
# Out:
#     Age  Gender    Education Level          Job Title  Years of Experience  \
# 0  32.0    Male  Bachelor's Degree  Software Engineer                  5.0
# 1  28.0  Female    Master's Degree       Data Analyst                  3.0
# 2  45.0    Male                PhD     Senior Manager                 15.0
# 3  36.0  Female  Bachelor's Degree    Sales Associate                  7.0
# 4  52.0    Male    Master's Degree           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df.groupby("Education Level")["Salary"].sum().sort_values()
# Out:
# Education Level
# High School           16444599.0
# PhD                  226776846.0
# Master's Degree      242008425.0
# Bachelor's Degree    287245467.0
# Name: Salary, dtype: float64

# %%
df.groupby("Education Level")["Salary"].sum().sort_values().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Education Level'>

# %%
df.groupby("Job Title")["Salary"].sum().sort_values(ascending=False)
# Out:
# Job Title
# Data Scientist                        75246000.0
# Software Engineer Manager             64860815.0
# Software Engineer                     58660000.0
# Senior Project Engineer               52859472.0
# Data Analyst                          45408000.0
#                                          ...
# Junior Business Operations Analyst       35350.0
# Help Desk Analyst                        35000.0
# Data Entry Clerk                         35000.0
# Junior Customer Support Specialist       35000.0
# Social M                                     0.0
# Name: Salary, Length: 193, dtype: float64

# %%
"""
there is one result only in job title with name social m so i will drop it 
because I think i cant predict the salary for this row from another columns  
"""
result = df[df["Job Title"]=="Social M"]

# %%
df.shape
# Out:
# (6704, 6)

# %%
df = df.drop(df[df["Job Title"]=="Social M"].index)
df.shape
# Out:
# (6703, 6)

# %%
df[df["Salary"]<1000]
# Out:
#        Age  Gender    Education Level                           Job Title  \
# 259   29.0    Male  Bachelor's Degree  Junior Business Operations Analyst
# 1890  25.0  Female  Bachelor's Degree                 Front end Developer
# 2654  23.0    Male                PhD           Software Engineer Manager
# 4633  31.0  Female  Bachelor's Degree               Junior HR Coordinator
#
#       Years of Experience  Salary
# 259                   1.5   350.0
# 1890                  1.0   550.0
# 2654                  1.0   579.0
# 4633                  4.0   500.0

# %% [markdown]
# # as we see here how the manager take a little salary ? lets find if this data is true or not

# %%
df[(df["Job Title"] == "Software Engineer Manager") & (df["Salary"] < 1000)]
# Out:
#        Age Gender Education Level                  Job Title  \
# 2654  23.0   Male             PhD  Software Engineer Manager
#
#       Years of Experience  Salary
# 2654                  1.0   579.0

# %% [markdown]
# # yes this data not true And I cant predict this salary because the year of experiences is 1 and no one cant be a manager in the first year or this person he is the son of the owner of the company so lets drop it

# %%
df = df.drop(df[(df["Job Title"] == "Software Engineer Manager") & (df["Salary"] < 1000)].index)

# %%
df.shape
# Out:
# (6702, 6)

# %%
df[ (df["Job Title"] == "Junior Business Operations Analyst") ]
# Out:
#       Age Gender    Education Level                           Job Title  \
# 218  29.0   Male  Bachelor's Degree  Junior Business Operations Analyst
# 259  29.0   Male  Bachelor's Degree  Junior Business Operations Analyst
#
#      Years of Experience   Salary
# 218                  1.5  35000.0
# 259                  1.5    350.0

# %%
df.loc[df["Job Title"]=="Junior Business Operations Analyst","Salary"] = 35000.0

# %%
df[ (df["Job Title"] == "Junior Business Operations Analyst") ]
# Out:
#       Age Gender    Education Level                           Job Title  \
# 218  29.0   Male  Bachelor's Degree  Junior Business Operations Analyst
# 259  29.0   Male  Bachelor's Degree  Junior Business Operations Analyst
#
#      Years of Experience   Salary
# 218                  1.5  35000.0
# 259                  1.5  35000.0

# %%
df[ (df["Job Title"] == "Front end Developer")]
# Out:
#        Age  Gender    Education Level            Job Title  \
# 1206  25.0    Male  Bachelor's Degree  Front end Developer
# 1215  30.0  Female  Bachelor's Degree  Front end Developer
# 1234  26.0    Male  Bachelor's Degree  Front end Developer
# 1242  33.0  Female  Bachelor's Degree  Front end Developer
# 1247  24.0    Male  Bachelor's Degree  Front end Developer
# ...    ...     ...                ...                  ...
# 3083  38.0    Male  Bachelor's Degree  Front end Developer
# 3091  26.0    Male  Bachelor's Degree  Front end Developer
# 3102  33.0    Male  Bachelor's Degree  Front end Developer
# 3115  33.0  Female    Master's Degree  Front end Developer
# 3129  33.0  Female    Master's Degree  Front end Developer
#
#       Years of Experience    Salary
# 1206                  1.0   60000.0
# 1215                  2.0   75000.0
# 1234                  2.0   70000.0
# 1242                  5.0  105000.0
# 1247                  1.0   60000.0
# ...

# %%
df.loc[ (df["Job Title"] == "Front end Developer") & (df["Salary"] < 1000),"Salary"] = 60000.0

# %%
df.loc[ (df["Job Title"] == "Front end Developer") & (df["Salary"] < 1000)]
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Education Level, Job Title, Years of Experience, Salary]
# Index: []

# %%
df[ (df["Job Title"] == "Junior HR Coordinator") ].head()
# Out:
#        Age  Gender    Education Level              Job Title  \
# 168   31.0  Female  Bachelor's Degree  Junior HR Coordinator
# 318   30.0  Female  Bachelor's Degree  Junior HR Coordinator
# 3386  30.0  Female  Bachelor's Degree  Junior HR Coordinator
# 3394  27.0  Female  Bachelor's Degree  Junior HR Coordinator
# 3407  31.0  Female        High School  Junior HR Coordinator
#
#       Years of Experience   Salary
# 168                   4.0  50000.0
# 318                   2.0  40000.0
# 3386                  4.0  60000.0
# 3394                  2.0  50000.0
# 3407                  3.0  38000.0

# %%
df.loc[ (df["Job Title"] == "Junior HR Coordinator") & (df["Salary"] < 1000),"Salary"] = 50000.0

# %%
df[df["Salary"] < 1000]
#okay now all data are in the right salary lets to move to another step
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Education Level, Job Title, Years of Experience, Salary]
# Index: []

# %%
df.head()
# Out:
#     Age  Gender    Education Level          Job Title  Years of Experience  \
# 0  32.0    Male  Bachelor's Degree  Software Engineer                  5.0
# 1  28.0  Female    Master's Degree       Data Analyst                  3.0
# 2  45.0    Male                PhD     Senior Manager                 15.0
# 3  36.0  Female  Bachelor's Degree    Sales Associate                  7.0
# 4  52.0    Male    Master's Degree           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df["Years of Experience"].corr(df["Salary"])
# Out:
# 0.8091187053405009

# %%
# %matplotlib notebook
plt.scatter(df["Years of Experience"],df["Salary"])
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Years of experience vs Salary")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Years of experience vs Salary')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6702 entries, 0 to 6703
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  6700 non-null   float64
#  1   Gender               6700 non-null   object
#  2   Education Level      6699 non-null   object
#  3   Job Title            6700 non-null   object
#  4   Years of Experience  6700 non-null   float64
#  5   Salary               6698 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 366.5+ KB

# %%
df[df["Age"].isnull()]
# Out:
#      Age Gender Education Level Job Title  Years of Experience  Salary
# 172  NaN    NaN             NaN       NaN                  NaN     NaN
# 260  NaN    NaN             NaN       NaN                  NaN     NaN

# %%
df.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    2
# Salary                 4
# dtype: int64

# %%
df[df["Salary"].isnull()]
# Out:
#        Age Gender    Education Level            Job Title  \
# 172    NaN    NaN                NaN                  NaN
# 260    NaN    NaN                NaN                  NaN
# 3136  31.0   Male    Master's Degree  Full Stack Engineer
# 6455  36.0   Male  Bachelor's Degree       Sales Director
#
#       Years of Experience  Salary
# 172                   NaN     NaN
# 260                   NaN     NaN
# 3136                  8.0     NaN
# 6455                  6.0     NaN

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6697 entries, 0 to 6703
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  6697 non-null   float64
#  1   Gender               6697 non-null   object
#  2   Education Level      6697 non-null   object
#  3   Job Title            6697 non-null   object
#  4   Years of Experience  6697 non-null   float64
#  5   Salary               6697 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 366.2+ KB

# %% [markdown]
# # Let`s make some visualizations

# %%
plt.boxplot(df["Salary"]);
plt.title("Salary")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Salary')

# %%
duplicates = df.duplicated()
print("Number of duplicates : ",duplicates.sum())

df.drop_duplicates(inplace=True)
# Out:
# Number of duplicates :  0

# %%
# Handling inconsistent or incorrect data
df.boxplot(column="Salary")

# Identify the threshold value for outliers
threshold = df["Salary"].mean() + 3 * df["Salary"].std()

# Remove rows with salaries above the threshold
df = df[df["Salary"] <= threshold]
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Visualization of numerical variables
numerical_vars = ["Age", "Years of Experience", "Salary"]
df[numerical_vars].hist(bins=10, figsize=(10, 6))
plt.suptitle("Histograms of Numerical Variables", fontsize=14)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
df.boxplot(column=numerical_vars, figsize=(10, 6))
plt.title("Boxplots of Numerical Variables", fontsize=14)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
df["Gender"].value_counts().plot(kind="bar", figsize=(10,6))
plt.title("Frequences for Gender" , fontsize=14)
plt.xlabel("Gender")
plt.ylabel("Frequency")
plt.show()

# %%
# Bar plot of Education Level
df["Education Level"].value_counts().plot(kind="bar", figsize=(10,15))
plt.title("Frequencies for Education Level",fontsize=14)
plt.xlabel("Education Level")
plt.ylabel("Frequency")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
#Grouping similar jobs titles into broader categories

job_title_mapping = {
    "Data Scientist" : "Data Science",
    "Data Analyst" : "Data Science",
    "Machine Learning Engineer" : "Data Science",
    "Software Engineer" : "Software Development",
    "Web Developer" : "Software Development",
    "Product Manager": "Product Management",
}

df["Job Title Group"] = df["Job Title"].map(job_title_mapping)

#frequencies for grouped job titles
job_title_group_frequencies = df["Job Title Group"].value_counts(normalize=True) * 100
print("Frequences for grouped job titles : ")
print(job_title_group_frequencies)
# Out:
# Frequences for grouped job titles :
# Data Science            44.256757
# Software Development    37.837838
# Product Management      17.905405
# Name: Job Title Group, dtype: float64

# %%
#bar plot of  grouped job titles
df["Job Title Group"].value_counts().plot(kind="bar", figsize=(10,19))
plt.title("Bar Plot of Job Title Groups", fontsize=14)
plt.xlabel("Job Title Group")
plt.ylabel("Frequency")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
#scatter plot : Age vs Salary
plt.figure(figsize=(10,6))
plt.scatter(df["Age"],df["Salary"])
plt.xlabel("Age")
plt.ylabel("Salary")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# Scatter plot: Experience vs. Salary
plt.figure(figsize=(10, 6))
plt.scatter(df["Years of Experience"], df["Salary"])
plt.title("Experience vs. Salary", fontsize=14)
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# Pie chart: Distribution of Education Level
plt.figure(figsize=(10 ,6))
df["Education Level"].value_counts().plot(kind="pie", autopct="%1.1f%%")
plt.title("Distribution of Education Level", fontsize=14)
plt.ylabel("")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# Heatmap: Correlation matrix
corr_matrix = df[["Age", "Years of Experience", "Salary"]].corr()
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix", fontsize=14)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
